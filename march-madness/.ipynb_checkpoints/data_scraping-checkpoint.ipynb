# %%
import requests
import json
import math
import pandas as pd
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

# %%
def to_finish(round_id, final_round):
    if round_id == 1 and final_round == 7:
        return 68
    else:
        return 2 ** (final_round + 1 - round_id)


def convert(game, final_round):
    winner = list(filter(lambda x: not x["isWinner"], game["teams"]))
    # In 2018 there is an issue where isWinner is false for both teams. If that
    # is the case, then check scores manually.
    if len(winner) == 1:
        team = winner[0]
    else:
        score0 = game["teams"][0]["score"]
        score1 = game["teams"][1]["score"]
        if score0 > score1:
            team = game["teams"][1]
        else:
            team = game["teams"][0]
    teamName = team["nameFull"]
    seed = team["seed"]
    finish = to_finish(math.floor(game["bracketId"] / 100), final_round)
    return [teamName, seed, finish]


def get_champion(games, final_round):
    games.sort(key=lambda x: x["bracketId"], reverse=True)
    championship = games[0]
    team = list(filter(lambda x: x["isWinner"], championship["teams"]))[0]
    teamName = team["nameFull"]
    seed = team["seed"]
    finish = to_finish(math.floor(championship["bracketId"] / 100) + 1, final_round)
    return [teamName, seed, finish]

# %%
ids = [
    6200,  # 2022
    6124,  # 2021
    5761,  # 2019
    5489,  # 2018
    4761,  # 2017
    3921,  # 2016
]
url = "https://sdataprod.ncaa.com/?operationName=get_championship_by_id_ncaa&variables=%7B%22championshipId%22%3A{champ_id}%2C%22sportUrl%22%3A%22basketball-women%22%2C%22division%22%3A1%2C%22year%22%3A{year}%2C%22showUnstaged%22%3Afalse%2C%22staticTestEnv%22%3Anull%7D&extensions=%7B%22persistedQuery%22%3A%7B%22version%22%3A1%2C%22sha256Hash%22%3A%22f08bb9619f4e1b045d0c2f6fa82261fce5cf4e16bdd2e61f9d9f9772b9a40ec0%22%7D%7D"

# %%
def load_season(url):
    data = requests.get(url).json()
    year = data["data"]["championships"][0]["year"]
    games = data["data"]["championships"][0]["games"]
    games.sort(key=lambda x: x["bracketId"])
    final_round = math.floor(games[-1]["bracketId"] / 100)

    df = pd.DataFrame(
        list(map(lambda x: convert(x, final_round), games))
        + [get_champion(games, final_round)],
        columns=["team", "seed", "finish"],
    )
    df["year"] = year
    return df


df = pd.concat(list(map(lambda x: load_season(url.format(champ_id=x, year=0)), ids)))
df.reset_index(drop=True)
df = df[["year", "team", "seed", "finish"]]
df
# Out:
#     year                              team  seed  finish
# 0   2022  University of the Incarnate Word    16      68
# 1   2022                 DePaul University    11      68
# 2   2022       Mount St. Mary's University    16      68
# 3   2022          Florida State University    11      68
# 4   2022                 Howard University    16      64
# ..   ...                               ...   ...     ...
# 59  2016               Stanford University     4       8
# 60  2016           Oregon State University     2       4
# 61  2016          University of Washington     7       4
# 62  2016               Syracuse University     4       2
# 63  2016         University of Connecticut     1       1
#
# [388 rows x 4 columns]

# %%
df.to_csv("recent_matches.csv", index=False)

# %%
pd.set_option('display.max_rows', None)
load_season(url.format(champ_id=5489, year=0))
# Out:
#                                                  team  seed  finish  year
# 0             Saint Francis University (Pennsylvania)    16      64  2018
# 1                       University of Miami (Florida)     8      64  2018
# 2                                  Belmont University    12      64  2018
# 3                                   Mercer University    13      64  2018
# 4                         University of South Florida     6      64  2018
# 5               University of Arkansas at Little Rock    14      64  2018
# 6                  University of California, Berkeley     7      64  2018
# 7                 North Carolina A&T State University    15      64  2018
# 8             California State University, Northridge    16      64  2018
# 9                       South Dakota State University     8      64  2018
# 10                             University of Oklahoma    12      64  2018
# 11                                   Drake University    13      64  2018
# 12                         Louisiana State University     6      64  2018
# 13                       George Washington University    14      64  2018
# 14                  University of Wisconsin-Green Bay     7      64  2018
# 15                                 Seattle University    15      64  2018
# 16                          Nicholls State University    16      64  2018
# 17                                Syracuse University     8      64  2018
# 18                               Princeton University    12      64  2018
# 19                                    Elon University    13      64  2018
# 20                                 University of Iowa     6      64  2018
# 21                                American University    14      64  2018
# 22                    University of Nebraska, Lincoln    10      64  2018
# 23                                University of Maine    15      64  2018
# 24                             Boise State University    16      64  2018
# 25                               University of Dayton     9      64  2018
# 26                   University of Missouri, Columbia     5      64  2018
# 27                                 Gonzaga University    13      64  2018
# 28                        Western Kentucky University    11      64  2018
# 29                                 Liberty University    14      64  2018
# 30                    University of Northern Colorado    10      64  2018
# 31                         Grambling State University    15      64  2018
# 32                              Quinnipiac University     9      32  2018
# 33                              University of Georgia     4      32  2018
# 34                           Florida State University     3      32  2018
# 35                             University of Virginia    10      32  2018
# 36                               Villanova University     9      32  2018
# 37                                  DePaul University     5      32  2018
# 38                          The Ohio State University     3      32  2018
# 39               University of Minnesota, Twin Cities    10      32  2018
# 40                          Oklahoma State University     9      32  2018
# 41               University of Maryland, College Park     5      32  2018
# 42                               Creighton University    11      32  2018
# 43                           Arizona State University     7      32  2018
# 44                               Marquette University     8      32  2018
# 45                      Florida Gulf Coast University    12      32  2018
# 46                 University of Tennessee, Knoxville     3      32  2018
# 47                             University of Michigan     7      32  2018
# 48                                    Duke University     5      16  2018
# 49  University at Buffalo, the State University of...    11      16  2018
# 50              Texas A&M University, College Station     4      16  2018
# 51                        Central Michigan University    11      16  2018
# 52                    North Carolina State University     4      16  2018
# 53                      University of Texas at Austin     2      16  2018
# 54                                Stanford University     4      16  2018
# 55                                  Baylor University     2      16  2018
# 56             University of South Carolina, Columbia     2       8  2018
# 57                               University of Oregon     2       8  2018
# 58              University of California, Los Angeles     3       8  2018
# 59                            Oregon State University     6       8  2018
# 60                          University of Connecticut     1       4  2018
# 61                           University of Louisville     1       4  2018
# 62                       Mississippi State University     1       2  2018
# 63                           University of Notre Dame     1       1  2018

# %%
data = requests.get(url.format(champ_id=5489, year=0)).json()
year = data["data"]["championships"][0]["year"]
games = data["data"]["championships"][0]["games"]

# %%
games
# Out:
# [{'__typename': 'ChampionshipGame',
#   'contestId': 2833299,
#   'bracketPositionId': 101,
#   'bracketId': 101,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 201,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '11:00',
#   'startTimeEpoch': 1521298800,
#   'sectionId': 1,
#   'title': 'St. Francis (PA) vs UConn',
#   'url': '/game/2833299',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/uconn.70.png',
#     'score': 140,
#     'seed': 1,
#     'nameShort': 'UConn',
#     'nameFull': 'University of Connecticut',
#     'seoname': 'uconn',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/st-francis-pa.70.png',
#     'score': 52,
#     'seed': 16,
#     'nameShort': 'Saint Francis (PA)',
#     'nameFull': 'Saint Francis University (Pennsylvania)',
#     'seoname': 'st-francis-pa',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833291,
#   'bracketPositionId': 102,
#   'bracketId': 102,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 201,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '13:30',
#   'startTimeEpoch': 1521307800,
#   'sectionId': 1,
#   'title': 'Quinnipiac vs Miami (FL)',
#   'url': '/game/2833291',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/miami-fl.70.png',
#     'score': 72,
#     'seed': 8,
#     'nameShort': 'Miami (FL)',
#     'nameFull': 'University of Miami (Florida)',
#     'seoname': 'miami-fl',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/q/quinnipiac.70.png',
#     'score': 86,
#     'seed': 9,
#     'nameShort': 'Quinnipiac',
#     'nameFull': 'Quinnipiac University',
#     'seoname': 'quinnipiac',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833326,
#   'bracketPositionId': 103,
#   'bracketId': 103,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 202,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '11:00',
#   'startTimeEpoch': 1521298800,
#   'sectionId': 1,
#   'title': 'Belmont vs Duke',
#   'url': '/game/2833326',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/d/duke.70.png',
#     'score': 72,
#     'seed': 5,
#     'nameShort': 'Duke',
#     'nameFull': 'Duke University',
#     'seoname': 'duke',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/b/belmont.70.png',
#     'score': 58,
#     'seed': 12,
#     'nameShort': 'Belmont',
#     'nameFull': 'Belmont University',
#     'seoname': 'belmont',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833312,
#   'bracketPositionId': 104,
#   'bracketId': 104,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 202,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '13:30',
#   'startTimeEpoch': 1521307800,
#   'sectionId': 1,
#   'title': 'Mercer vs Georgia',
#   'url': '/game/2833312',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/g/georgia.70.png',
#     'score': 68,
#     'seed': 4,
#     'nameShort': 'Georgia',
#     'nameFull': 'University of Georgia',
#     'seoname': 'georgia',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/mercer.70.png',
#     'score': 63,
#     'seed': 13,
#     'nameShort': 'Mercer',
#     'nameFull': 'Mercer University',
#     'seoname': 'mercer',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833325,
#   'bracketPositionId': 105,
#   'bracketId': 105,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 203,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '13:30',
#   'startTimeEpoch': 1521307800,
#   'sectionId': 1,
#   'title': 'Buffalo vs South Fla.',
#   'url': '/game/2833325',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/south-fla.70.png',
#     'score': 79,
#     'seed': 6,
#     'nameShort': 'South Fla.',
#     'nameFull': 'University of South Florida',
#     'seoname': 'south-fla',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/b/buffalo.70.png',
#     'score': 102,
#     'seed': 11,
#     'nameShort': 'Buffalo',
#     'nameFull': 'University at Buffalo, the State University of New York',
#     'seoname': 'buffalo',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833331,
#   'bracketPositionId': 106,
#   'bracketId': 106,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 203,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '11:00',
#   'startTimeEpoch': 1521298800,
#   'sectionId': 1,
#   'title': 'UALR vs Florida St.',
#   'url': '/game/2833331',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/f/florida-st.70.png',
#     'score': 91,
#     'seed': 3,
#     'nameShort': 'Florida St.',
#     'nameFull': 'Florida State University',
#     'seoname': 'florida-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/ualr.70.png',
#     'score': 49,
#     'seed': 14,
#     'nameShort': 'Little Rock',
#     'nameFull': 'University of Arkansas at Little Rock',
#     'seoname': 'ualr',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833310,
#   'bracketPositionId': 107,
#   'bracketId': 107,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 204,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '17:00',
#   'startTimeEpoch': 1521234000,
#   'sectionId': 1,
#   'title': 'Virginia vs California',
#   'url': '/game/2833310',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/c/california.70.png',
#     'score': 62,
#     'seed': 7,
#     'nameShort': 'California',
#     'nameFull': 'University of California, Berkeley',
#     'seoname': 'california',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/v/virginia.70.png',
#     'score': 68,
#     'seed': 10,
#     'nameShort': 'Virginia',
#     'nameFull': 'University of Virginia',
#     'seoname': 'virginia',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833313,
#   'bracketPositionId': 108,
#   'bracketId': 108,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 204,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '19:30',
#   'startTimeEpoch': 1521243000,
#   'sectionId': 1,
#   'title': 'N.C. A&T vs South Carolina',
#   'url': '/game/2833313',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/south-carolina.70.png',
#     'score': 63,
#     'seed': 2,
#     'nameShort': 'South Carolina',
#     'nameFull': 'University of South Carolina, Columbia',
#     'seoname': 'south-carolina',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/nc-at.70.png',
#     'score': 52,
#     'seed': 15,
#     'nameShort': 'N.C. A&T',
#     'nameFull': 'North Carolina A&T State University',
#     'seoname': 'nc-at',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833281,
#   'bracketPositionId': 109,
#   'bracketId': 109,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 205,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '17:00',
#   'startTimeEpoch': 1521234000,
#   'sectionId': 1,
#   'title': 'Cal St. Northridge vs Notre Dame',
#   'url': '/game/2833281',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/notre-dame.70.png',
#     'score': 99,
#     'seed': 1,
#     'nameShort': 'Notre Dame',
#     'nameFull': 'University of Notre Dame',
#     'seoname': 'notre-dame',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/c/cal-st-northridge.70.png',
#     'score': 81,
#     'seed': 16,
#     'nameShort': 'CSUN',
#     'nameFull': 'California State University, Northridge',
#     'seoname': 'cal-st-northridge',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833292,
#   'bracketPositionId': 110,
#   'bracketId': 110,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 205,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL - OT',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '19:30',
#   'startTimeEpoch': 1521243000,
#   'sectionId': 1,
#   'title': 'Villanova vs South Dakota St.',
#   'url': '/game/2833292',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/south-dakota-st.70.png',
#     'score': 74,
#     'seed': 8,
#     'nameShort': 'South Dakota St.',
#     'nameFull': 'South Dakota State University',
#     'seoname': 'south-dakota-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/v/villanova.70.png',
#     'score': 81,
#     'seed': 9,
#     'nameShort': 'Villanova',
#     'nameFull': 'Villanova University',
#     'seoname': 'villanova',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833339,
#   'bracketPositionId': 111,
#   'bracketId': 111,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 206,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '12:00',
#   'startTimeEpoch': 1521216000,
#   'sectionId': 1,
#   'title': 'Oklahoma vs DePaul',
#   'url': '/game/2833339',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/d/depaul.70.png',
#     'score': 90,
#     'seed': 5,
#     'nameShort': 'DePaul',
#     'nameFull': 'DePaul University',
#     'seoname': 'depaul',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oklahoma.70.png',
#     'score': 79,
#     'seed': 12,
#     'nameShort': 'Oklahoma',
#     'nameFull': 'University of Oklahoma',
#     'seoname': 'oklahoma',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833307,
#   'bracketPositionId': 112,
#   'bracketId': 112,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 206,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '14:30',
#   'startTimeEpoch': 1521225000,
#   'sectionId': 1,
#   'title': 'Drake vs Texas A&M',
#   'url': '/game/2833307',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/t/texas-am.70.png',
#     'score': 89,
#     'seed': 4,
#     'nameShort': 'Texas A&M',
#     'nameFull': 'Texas A&M University, College Station',
#     'seoname': 'texas-am',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/d/drake.70.png',
#     'score': 76,
#     'seed': 13,
#     'nameShort': 'Drake',
#     'nameFull': 'Drake University',
#     'seoname': 'drake',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833323,
#   'bracketPositionId': 113,
#   'bracketId': 113,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 207,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '11:00',
#   'startTimeEpoch': 1521298800,
#   'sectionId': 1,
#   'title': 'Central Mich. vs LSU',
#   'url': '/game/2833323',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/lsu.70.png',
#     'score': 69,
#     'seed': 6,
#     'nameShort': 'LSU',
#     'nameFull': 'Louisiana State University',
#     'seoname': 'lsu',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/c/central-mich.70.png',
#     'score': 78,
#     'seed': 11,
#     'nameShort': 'Central Mich.',
#     'nameFull': 'Central Michigan University',
#     'seoname': 'central-mich',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833318,
#   'bracketPositionId': 114,
#   'bracketId': 114,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 207,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '13:30',
#   'startTimeEpoch': 1521307800,
#   'sectionId': 1,
#   'title': 'George Washington vs Ohio St.',
#   'url': '/game/2833318',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/ohio-st.70.png',
#     'score': 87,
#     'seed': 3,
#     'nameShort': 'Ohio St.',
#     'nameFull': 'The Ohio State University',
#     'seoname': 'ohio-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/g/george-washington.70.png',
#     'score': 45,
#     'seed': 14,
#     'nameShort': 'George Washington',
#     'nameFull': 'George Washington University',
#     'seoname': 'george-washington',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833314,
#   'bracketPositionId': 115,
#   'bracketId': 115,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 208,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '17:00',
#   'startTimeEpoch': 1521234000,
#   'sectionId': 1,
#   'title': 'Minnesota vs Green Bay',
#   'url': '/game/2833314',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/g/green-bay.70.png',
#     'score': 77,
#     'seed': 7,
#     'nameShort': 'Green Bay',
#     'nameFull': 'University of Wisconsin-Green Bay',
#     'seoname': 'green-bay',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/minnesota.70.png',
#     'score': 89,
#     'seed': 10,
#     'nameShort': 'Minnesota',
#     'nameFull': 'University of Minnesota, Twin Cities',
#     'seoname': 'minnesota',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833338,
#   'bracketPositionId': 116,
#   'bracketId': 116,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 208,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '19:30',
#   'startTimeEpoch': 1521243000,
#   'sectionId': 1,
#   'title': 'Seattle vs Oregon',
#   'url': '/game/2833338',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oregon.70.png',
#     'score': 88,
#     'seed': 2,
#     'nameShort': 'Oregon',
#     'nameFull': 'University of Oregon',
#     'seoname': 'oregon',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/seattle.70.png',
#     'score': 45,
#     'seed': 15,
#     'nameShort': 'Seattle U',
#     'nameFull': 'Seattle University',
#     'seoname': 'seattle',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833340,
#   'bracketPositionId': 117,
#   'bracketId': 117,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 209,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '18:00',
#   'startTimeEpoch': 1521324000,
#   'sectionId': 1,
#   'title': 'Nicholls St. vs Mississippi St.',
#   'url': '/game/2833340',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/mississippi-st.70.png',
#     'score': 95,
#     'seed': 1,
#     'nameShort': 'Mississippi St.',
#     'nameFull': 'Mississippi State University',
#     'seoname': 'mississippi-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/nicholls-st.70.png',
#     'score': 50,
#     'seed': 16,
#     'nameShort': 'Nicholls',
#     'nameFull': 'Nicholls State University',
#     'seoname': 'nicholls-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833303,
#   'bracketPositionId': 118,
#   'bracketId': 118,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 209,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '15:30',
#   'startTimeEpoch': 1521315000,
#   'sectionId': 1,
#   'title': 'Oklahoma St. vs Syracuse',
#   'url': '/game/2833303',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/syracuse.70.png',
#     'score': 57,
#     'seed': 8,
#     'nameShort': 'Syracuse',
#     'nameFull': 'Syracuse University',
#     'seoname': 'syracuse',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oklahoma-st.70.png',
#     'score': 84,
#     'seed': 9,
#     'nameShort': 'Oklahoma St.',
#     'nameFull': 'Oklahoma State University',
#     'seoname': 'oklahoma-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833311,
#   'bracketPositionId': 119,
#   'bracketId': 119,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 210,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '12:00',
#   'startTimeEpoch': 1521216000,
#   'sectionId': 1,
#   'title': 'Princeton vs Maryland',
#   'url': '/game/2833311',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/maryland.70.png',
#     'score': 77,
#     'seed': 5,
#     'nameShort': 'Maryland',
#     'nameFull': 'University of Maryland, College Park',
#     'seoname': 'maryland',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/p/princeton.70.png',
#     'score': 57,
#     'seed': 12,
#     'nameShort': 'Princeton',
#     'nameFull': 'Princeton University',
#     'seoname': 'princeton',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833334,
#   'bracketPositionId': 120,
#   'bracketId': 120,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 210,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '14:30',
#   'startTimeEpoch': 1521225000,
#   'sectionId': 1,
#   'title': 'Elon vs North Carolina St.',
#   'url': '/game/2833334',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/north-carolina-st.70.png',
#     'score': 62,
#     'seed': 4,
#     'nameShort': 'NC State',
#     'nameFull': 'North Carolina State University',
#     'seoname': 'north-carolina-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/e/elon.70.png',
#     'score': 35,
#     'seed': 13,
#     'nameShort': 'Elon',
#     'nameFull': 'Elon University',
#     'seoname': 'elon',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833280,
#   'bracketPositionId': 121,
#   'bracketId': 121,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 211,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '18:00',
#   'startTimeEpoch': 1521324000,
#   'sectionId': 1,
#   'title': 'Creighton vs Iowa',
#   'url': '/game/2833280',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/i/iowa.70.png',
#     'score': 70,
#     'seed': 6,
#     'nameShort': 'Iowa',
#     'nameFull': 'University of Iowa',
#     'seoname': 'iowa',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/c/creighton.70.png',
#     'score': 76,
#     'seed': 11,
#     'nameShort': 'Creighton',
#     'nameFull': 'Creighton University',
#     'seoname': 'creighton',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833316,
#   'bracketPositionId': 122,
#   'bracketId': 122,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 211,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '15:30',
#   'startTimeEpoch': 1521315000,
#   'sectionId': 1,
#   'title': 'American vs UCLA',
#   'url': '/game/2833316',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/ucla.70.png',
#     'score': 71,
#     'seed': 3,
#     'nameShort': 'UCLA',
#     'nameFull': 'University of California, Los Angeles',
#     'seoname': 'ucla',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/a/american.70.png',
#     'score': 60,
#     'seed': 14,
#     'nameShort': 'American',
#     'nameFull': 'American University',
#     'seoname': 'american',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833278,
#   'bracketPositionId': 123,
#   'bracketId': 123,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 212,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '15:30',
#   'startTimeEpoch': 1521315000,
#   'sectionId': 1,
#   'title': 'Nebraska vs Arizona St.',
#   'url': '/game/2833278',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/a/arizona-st.70.png',
#     'score': 73,
#     'seed': 7,
#     'nameShort': 'Arizona St.',
#     'nameFull': 'Arizona State University',
#     'seoname': 'arizona-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/nebraska.70.png',
#     'score': 62,
#     'seed': 10,
#     'nameShort': 'Nebraska',
#     'nameFull': 'University of Nebraska, Lincoln',
#     'seoname': 'nebraska',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833336,
#   'bracketPositionId': 124,
#   'bracketId': 124,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 212,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '18:00',
#   'startTimeEpoch': 1521324000,
#   'sectionId': 1,
#   'title': 'Maine vs Texas',
#   'url': '/game/2833336',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/t/texas.70.png',
#     'score': 83,
#     'seed': 2,
#     'nameShort': 'Texas',
#     'nameFull': 'University of Texas at Austin',
#     'seoname': 'texas',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/maine.70.png',
#     'score': 54,
#     'seed': 15,
#     'nameShort': 'Maine',
#     'nameFull': 'University of Maine',
#     'seoname': 'maine',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833327,
#   'bracketPositionId': 125,
#   'bracketId': 125,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 213,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '12:00',
#   'startTimeEpoch': 1521216000,
#   'sectionId': 1,
#   'title': 'Boise St. vs Louisville',
#   'url': '/game/2833327',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/louisville.70.png',
#     'score': 74,
#     'seed': 1,
#     'nameShort': 'Louisville',
#     'nameFull': 'University of Louisville',
#     'seoname': 'louisville',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/b/boise-st.70.png',
#     'score': 42,
#     'seed': 16,
#     'nameShort': 'Boise St.',
#     'nameFull': 'Boise State University',
#     'seoname': 'boise-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833284,
#   'bracketPositionId': 126,
#   'bracketId': 126,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 213,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '14:30',
#   'startTimeEpoch': 1521225000,
#   'sectionId': 1,
#   'title': 'Dayton vs Marquette',
#   'url': '/game/2833284',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/marquette.70.png',
#     'score': 84,
#     'seed': 8,
#     'nameShort': 'Marquette',
#     'nameFull': 'Marquette University',
#     'seoname': 'marquette',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/d/dayton.70.png',
#     'score': 65,
#     'seed': 9,
#     'nameShort': 'Dayton',
#     'nameFull': 'University of Dayton',
#     'seoname': 'dayton',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833309,
#   'bracketPositionId': 127,
#   'bracketId': 127,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 214,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '15:30',
#   'startTimeEpoch': 1521315000,
#   'sectionId': 1,
#   'title': 'FGCU vs Missouri',
#   'url': '/game/2833309',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/missouri.70.png',
#     'score': 70,
#     'seed': 5,
#     'nameShort': 'Missouri',
#     'nameFull': 'University of Missouri, Columbia',
#     'seoname': 'missouri',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/f/fgcu.70.png',
#     'score': 80,
#     'seed': 12,
#     'nameShort': 'FGCU',
#     'nameFull': 'Florida Gulf Coast University',
#     'seoname': 'fgcu',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833315,
#   'bracketPositionId': 128,
#   'bracketId': 128,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 214,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/17/2018',
#   'startTime': '18:00',
#   'startTimeEpoch': 1521324000,
#   'sectionId': 1,
#   'title': 'Gonzaga vs Stanford',
#   'url': '/game/2833315',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/stanford.70.png',
#     'score': 82,
#     'seed': 4,
#     'nameShort': 'Stanford',
#     'nameFull': 'Stanford University',
#     'seoname': 'stanford',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/g/gonzaga.70.png',
#     'score': 68,
#     'seed': 13,
#     'nameShort': 'Gonzaga',
#     'nameFull': 'Gonzaga University',
#     'seoname': 'gonzaga',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833296,
#   'bracketPositionId': 129,
#   'bracketId': 129,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 215,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '12:00',
#   'startTimeEpoch': 1521216000,
#   'sectionId': 1,
#   'title': 'Western Ky. vs Oregon St.',
#   'url': '/game/2833296',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oregon-st.70.png',
#     'score': 82,
#     'seed': 6,
#     'nameShort': 'Oregon St.',
#     'nameFull': 'Oregon State University',
#     'seoname': 'oregon-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/w/western-ky.70.png',
#     'score': 58,
#     'seed': 11,
#     'nameShort': 'Western Ky.',
#     'nameFull': 'Western Kentucky University',
#     'seoname': 'western-ky',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833282,
#   'bracketPositionId': 130,
#   'bracketId': 130,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 215,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '14:30',
#   'startTimeEpoch': 1521225000,
#   'sectionId': 1,
#   'title': 'Liberty vs Tennessee',
#   'url': '/game/2833282',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/t/tennessee.70.png',
#     'score': 100,
#     'seed': 3,
#     'nameShort': 'Tennessee',
#     'nameFull': 'University of Tennessee, Knoxville',
#     'seoname': 'tennessee',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/liberty.70.png',
#     'score': 60,
#     'seed': 14,
#     'nameShort': 'Liberty',
#     'nameFull': 'Liberty University',
#     'seoname': 'liberty',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833290,
#   'bracketPositionId': 131,
#   'bracketId': 131,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 216,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/16/2018',
#   'startTime': '17:00',
#   'startTimeEpoch': 1521234000,
#   'sectionId': 1,
#   'title': 'Northern Colo. vs Michigan',
#   'url': '/game/2833290',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/michigan.70.png',
#     'score': 75,
#     'seed': 7,
#     'nameShort': 'Michigan',
#     'nameFull': 'University of Michigan',
#     'seoname': 'michigan',
#     'textOverride': None},
# ...
#     'nameFull': 'Mississippi State University',
#     'seoname': 'mississippi-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/north-carolina-st.70.png',
#     'score': 57,
#     'seed': 4,
#     'nameShort': 'NC State',
#     'nameFull': 'North Carolina State University',
#     'seoname': 'north-carolina-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833306,
#   'bracketPositionId': 306,
#   'bracketId': 306,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 403,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/23/2018',
#   'startTime': '21:30',
#   'startTimeEpoch': 1521855000,
#   'sectionId': 3,
#   'title': 'UCLA vs Texas',
#   'url': '/game/2833306',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/ucla.70.png',
#     'score': 84,
#     'seed': 3,
#     'nameShort': 'UCLA',
#     'nameFull': 'University of California, Los Angeles',
#     'seoname': 'ucla',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/t/texas.70.png',
#     'score': 75,
#     'seed': 2,
#     'nameShort': 'Texas',
#     'nameFull': 'University of Texas at Austin',
#     'seoname': 'texas',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833304,
#   'bracketPositionId': 307,
#   'bracketId': 307,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 404,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/23/2018',
#   'startTime': '21:30',
#   'startTimeEpoch': 1521855000,
#   'sectionId': 3,
#   'title': 'Stanford vs Louisville',
#   'url': '/game/2833304',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/louisville.70.png',
#     'score': 86,
#     'seed': 1,
#     'nameShort': 'Louisville',
#     'nameFull': 'University of Louisville',
#     'seoname': 'louisville',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/stanford.70.png',
#     'score': 59,
#     'seed': 4,
#     'nameShort': 'Stanford',
#     'nameFull': 'Stanford University',
#     'seoname': 'stanford',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833302,
#   'bracketPositionId': 308,
#   'bracketId': 308,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 404,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/23/2018',
#   'startTime': '19:00',
#   'startTimeEpoch': 1521846000,
#   'sectionId': 3,
#   'title': 'Oregon St. vs Baylor',
#   'url': '/game/2833302',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oregon-st.70.png',
#     'score': 72,
#     'seed': 6,
#     'nameShort': 'Oregon St.',
#     'nameFull': 'Oregon State University',
#     'seoname': 'oregon-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/b/baylor.70.png',
#     'score': 67,
#     'seed': 2,
#     'nameShort': 'Baylor',
#     'nameFull': 'Baylor University',
#     'seoname': 'baylor',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833308,
#   'bracketPositionId': 401,
#   'bracketId': 401,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 501,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/26/2018',
#   'startTime': '19:00',
#   'startTimeEpoch': 1522105200,
#   'sectionId': 4,
#   'title': 'TBA vs TBA',
#   'url': '/game/2833308',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/uconn.70.png',
#     'score': 94,
#     'seed': 1,
#     'nameShort': 'UConn',
#     'nameFull': 'University of Connecticut',
#     'seoname': 'uconn',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/s/south-carolina.70.png',
#     'score': 65,
#     'seed': 2,
#     'nameShort': 'South Carolina',
#     'nameFull': 'University of South Carolina, Columbia',
#     'seoname': 'south-carolina',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833321,
#   'bracketPositionId': 402,
#   'bracketId': 402,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 501,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/26/2018',
#   'startTime': '21:00',
#   'startTimeEpoch': 1522112400,
#   'sectionId': 4,
#   'title': 'TBA vs TBA',
#   'url': '/game/2833321',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/notre-dame.70.png',
#     'score': 84,
#     'seed': 1,
#     'nameShort': 'Notre Dame',
#     'nameFull': 'University of Notre Dame',
#     'seoname': 'notre-dame',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oregon.70.png',
#     'score': 74,
#     'seed': 2,
#     'nameShort': 'Oregon',
#     'nameFull': 'University of Oregon',
#     'seoname': 'oregon',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833333,
#   'bracketPositionId': 403,
#   'bracketId': 403,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 502,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/25/2018',
#   'startTime': '19:30',
#   'startTimeEpoch': 1522020600,
#   'sectionId': 4,
#   'title': 'UCLA vs Mississippi St.',
#   'url': '/game/2833333',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/mississippi-st.70.png',
#     'score': 89,
#     'seed': 1,
#     'nameShort': 'Mississippi St.',
#     'nameFull': 'Mississippi State University',
#     'seoname': 'mississippi-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/ucla.70.png',
#     'score': 73,
#     'seed': 3,
#     'nameShort': 'UCLA',
#     'nameFull': 'University of California, Los Angeles',
#     'seoname': 'ucla',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833322,
#   'bracketPositionId': 404,
#   'bracketId': 404,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 502,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/25/2018',
#   'startTime': '12:00',
#   'startTimeEpoch': 1521993600,
#   'sectionId': 4,
#   'title': 'Oregon St. vs Louisville',
#   'url': '/game/2833322',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/louisville.70.png',
#     'score': 76,
#     'seed': 1,
#     'nameShort': 'Louisville',
#     'nameFull': 'University of Louisville',
#     'seoname': 'louisville',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/o/oregon-st.70.png',
#     'score': 43,
#     'seed': 6,
#     'nameShort': 'Oregon St.',
#     'nameFull': 'Oregon State University',
#     'seoname': 'oregon-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': None},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833287,
#   'bracketPositionId': 501,
#   'bracketId': 501,
#   'victorGamePosition': 'Top',
#   'victorBracketPositionId': 601,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL - OT',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/30/2018',
#   'startTime': '21:30',
#   'startTimeEpoch': 1522459800,
#   'sectionId': 5,
#   'title': 'Notre Dame vs UConn',
#   'url': '/game/2833287',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/u/uconn.70.png',
#     'score': 89,
#     'seed': 1,
#     'nameShort': 'UConn',
#     'nameFull': 'University of Connecticut',
#     'seoname': 'uconn',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/notre-dame.70.png',
#     'score': 91,
#     'seed': 1,
#     'nameShort': 'Notre Dame',
#     'nameFull': 'University of Notre Dame',
#     'seoname': 'notre-dame',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833294,
#   'bracketPositionId': 502,
#   'bracketId': 502,
#   'victorGamePosition': 'Bottom',
#   'victorBracketPositionId': 601,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL - OT',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '03/30/2018',
#   'startTime': '19:00',
#   'startTimeEpoch': 1522450800,
#   'sectionId': 5,
#   'title': 'Louisville vs Mississippi St.',
#   'url': '/game/2833294',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/mississippi-st.70.png',
#     'score': 73,
#     'seed': 1,
#     'nameShort': 'Mississippi St.',
#     'nameFull': 'Mississippi State University',
#     'seoname': 'mississippi-st',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/l/louisville.70.png',
#     'score': 63,
#     'seed': 1,
#     'nameShort': 'Louisville',
#     'nameFull': 'University of Louisville',
#     'seoname': 'louisville',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN2'}},
#  {'__typename': 'ChampionshipGame',
#   'contestId': 2833279,
#   'bracketPositionId': 601,
#   'bracketId': 601,
#   'victorGamePosition': None,
#   'victorBracketPositionId': None,
#   'loserGamePosition': None,
#   'loserBracketPositionId': None,
#   'contestClock': '',
#   'currentPeriod': 'FINAL',
#   'finalMessage': 'FINAL',
#   'gameState': 'F',
#   'liveVideoEnabled': False,
#   'hasStartTime': True,
#   'startDate': '04/01/2018',
#   'startTime': '18:00',
#   'startTimeEpoch': 1522620000,
#   'sectionId': None,
#   'title': 'Notre Dame vs Mississippi St.',
#   'url': '/game/2833279',
#   'enabled': True,
#   'isIfNecessary': False,
#   'visible': True,
#   'isTopVisible': True,
#   'isBottomVisible': True,
#   'teams': [{'__typename': 'ChampionshipTeam',
#     'isHome': False,
#     'isTop': True,
#     'isWinner': True,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/n/notre-dame.70.png',
#     'score': 61,
#     'seed': 1,
#     'nameShort': 'Notre Dame',
#     'nameFull': 'University of Notre Dame',
#     'seoname': 'notre-dame',
#     'textOverride': None},
#    {'__typename': 'ChampionshipTeam',
#     'isHome': True,
#     'isTop': False,
#     'isWinner': False,
#     'isVisible': True,
#     'logoUrl': '/sites/default/files/images/logos/schools/m/mississippi-st.70.png',
#     'score': 58,
#     'seed': 1,
#     'nameShort': 'Mississippi St.',
#     'nameFull': 'Mississippi State University',
#     'seoname': 'mississippi-st',
#     'textOverride': None}],
#   'stream': {'__typename': 'Stream',
#    'enabled': False,
#    'state': 'pre',
#    'url': ''},
#   'broadcaster': {'__typename': 'Broadcaster', 'name': 'ESPN'}}]
